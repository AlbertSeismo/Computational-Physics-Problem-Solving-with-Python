# %% [markdown]
# # Chapter 7: TRIAL-AND-ERROR SEARCHING AND DATA FITTING

# %% [markdown]
# ![](1.jpg)

# %% [markdown]
# ![](2.jpg)

# %% [markdown]
# ![](3.jpg)

# %% [markdown]
# ![](4-copy.jpg)

# %% [markdown]
# # TASK: CHAPTER 7: IMPLEMENTATION: BISECTION ALGORITHM

# %% [markdown]
# ![](4a.jpg)

# %% [markdown]
# ![](05.jpg)

# %% [markdown]
# # TASK: CHAPTER 7: IMPLEMENTATION: NEWTON-RAPHSON ALGORITHM

# %% [markdown]
# ![](5a.jpg)

# %% [markdown]
# ![](6.jpg)

# %% [markdown]
# ![](7.jpg)

# %% [markdown]
# # IMPLEMENTATION: NEWTON-RAPHSON ALGORITHM EXERCISE

# %% [markdown]
# ![](8.jpg)

# %% [markdown]
# # LET'S CODE!!!

# %% [markdown]
# # 7.2.1 Implementation of Bisection Algorithm and Newton Raphson Method

# %%
#Page 144 Implementation: Bisection Algorithm
import matplotlib.pyplot as plt
from numpy import *
from scipy import interpolate 
# %matplotlib notebook

#TASK 1&2: Visualizing the function
#The function to call tangent
def ftan(x):
    return sqrt(10-x)*tan(sqrt(10-x))-sqrt(x)

#Lets write the bisection method function for tangent
def bisection_tan(xplus, xminus,n,eps):
    for i in range (0,n):
        x = (xplus+xminus)/2
        print(i,x,ftan(x))     #This is where you had a mistake of f(x) instead of fb(x) so it was making your code run wrongly
        if (ftan(x)*ftan(xplus))>0 :
            xplus = x
        else :
            xminus = x
        if abs(ftan(x)) <= eps :
            print("The root is found with a value: ",x," with a precision = ",eps,ftan(x))
            return x
        if i == (n-1):
            print("The root is not found")
a = 6
b = 9.9
eps = 1e-6
n = 100
E = arange(a,b,0.05)

#Computing the root if it available (but remember tan has some singularities around the y-axis as x=0, tan(x)=sin(x)/cos(x))
#it approaches infinity
root = bisection_tan(a,b,n,eps)

#Lets visualize the function by plotting
plt.plot(E,ftan(E))
#plt.plot(x,f(x))
plt.grid()
plt.title("A plot of Tangent function with some singularities\n")
plt.xlabel("X")
plt.ylabel("ftan(x)")
plt.show()

"""In mathematics, a singularity is in general a point at which a given mathematical object is not defined, 
or a point where the mathematical object ceases to be well-behaved in some particular way, 
such as the lack of differentiability or analyticity. For example, the real function f(x)=1/x 
has a singularity at x=0, where it seems to "explode" to plus/minus infinity and is hence not defined """
# Out:
# 0 7.95 7.413530899871207
# 1 6.975 -12.867821462896945
# 2 7.4625 -74.6142032912399
# 3 7.706250000000001 24.104360586984395
# 4 7.5843750000000005 91.04521746911198
# 5 7.5234375 -542.8924510007755
# 6 7.553906250000001 227.34786817174756
# 7 7.538671875 808.3369605436266
# 8 7.5310546875 -3199.9201002124187
# 9 7.534863281250001 2175.07023654811
# 10 7.532958984375 13700.316814414324
# 11 7.5320068359375 -8339.160731794878
# 12 7.53248291015625 -42549.467677293665
# 13 7.532720947265625 40429.19864668573
# 14 7.532601928710937 1629190.0259819478
# 15 7.532542419433593 -87376.34983429138
# 16 7.532572174072265 -184650.8744444311
# 17 7.532587051391602 -416501.73214180145
# 18 7.532594490051269 -1119089.130442662
# 19 7.532598209381103 -7148301.205657716
# 20 7.53260006904602 4220234.11804888
# 21 7.532599139213561 20605810.925219435
# 22 7.532598674297332 -21890591.17969372
# 23 7.532598906755446 702184472.8408352
# 24 7.532598790526389 -45189974.51764781
# ...

# %%
# %matplotlib notebook
#The function to call cotanget of x...
def fcot(x):
    return sqrt(x)*(1/(tan(sqrt(10-x))))-sqrt(10-x)

#Lets write the bisection method function for cotangent
def bisection_cot(xplus, xminus,n,eps):
    for i in range (0,n):
        x = (xplus+xminus)/2
        print(i,x,fcot(x))     
        if (fcot(x)*fcot(xplus))>0 :
            xplus = x
        else :
            xminus = x
        if abs(fcot(x)) <= eps :
            
            print("\nThe root is found with a value: ",x,"\n\nWith a precision = ",eps, "\n\nThe residue f(x)=",fcot(x))
            return x
        if i == (n-1):
            print("The root is not found")

#If you set a about -30, a=-30, b =9.9, you can clearly see where the curve cuts twice the x-axis about x=0.004 or less
#if you zoom further and at x=8.5927 
#but lets adjust the a to be small
a = 0.2
b = 9.9
eps = 1e-6
n = 100
E = arange(a,b,0.05)
#Computing the root using the bisection cot function

root = bisection_cot(a,b,n,eps)

#Visualizing the function of cotangent
plt.plot(E,fcot(E))
plt.grid()
plt.title("A plot of Cotangent function without some singularities for the larger root\n")
plt.xlabel("X")
plt.ylabel("fcot(x)")
plt.show()
# Out:
# 0 5.05 -3.947659005508041
# 1 7.475 -1.6388679972355598
# 2 8.6875 0.18886649385546406
# 3 8.08125 -0.8514113725772324
# 4 8.384375 -0.37624073255891777
# 5 8.5359375 -0.10756491540889468
# 6 8.61171875 0.0367493739955882
# 7 8.573828124999999 -0.03632317901496518
# 8 8.5927734375 -2.282778231332827e-05
# 9 8.60224609375 0.018303372853979427
# 10 8.597509765625 0.009125413952056016
# 11 8.5951416015625 0.004547592855873361
# 12 8.59395751953125 0.002261459272811406
# 13 8.593365478515626 0.0011190851528699586
# 14 8.593069458007813 0.0005480710651004639
# 15 8.592921447753906 0.0002626072398346224
# 16 8.592847442626953 0.00011988612880720062
# 17 8.592810440063477 4.852827331447429e-05
# 18 8.592791938781739 1.285002052453521e-05
# 19 8.592782688140868 -4.988937139405181e-06
# 20 8.592787313461304 3.93052763314472e-06
# 21 8.592785000801086 -5.292082683183708e-07
#
# The root is found with a value:  8.592785000801086
#
# With a precision =  1e-06
#
# ...

# %%
#Duplicate of the code to show the smaller root

# %matplotlib notebook
a = 0.0001
b = 0.04
eps = 1e-6
n = 100
E = arange(a,b,0.00001)
#Computing the root using the bisection cot function

root = bisection_cot(a,b,n,eps)

#Visualizing the function of cotangent
plt.plot(E,fcot(E))
plt.grid()
plt.title("A plot of Cotangent function without some singularities for a small root\n")
plt.xlabel("X")
plt.ylabel("fcot(x)")
plt.show()
# Out:
# 0 0.020050000000000002 4.9252694578922895
# 1 0.010075 2.0961859453179494
# 2 0.0050875 0.4258267843396437
# 3 0.00259375 -0.6502909751849328
# 4 0.0038406250000000003 -0.07543671392108564
# 5 0.0044640625 0.1821603595067467
# 6 0.004152343750000001 0.05531495287079524
# 7 0.0039964843750000005 -0.009541690805440428
# 8 0.0040744140625 0.02301233299078076
# 9 0.004035449218750001 0.006767242931943862
# 10 0.004015966796875001 -0.0013791801115088376
# 11 0.004025708007812501 0.0026960343855533253
# 12 0.004020837402343751 0.0006589288747278488
# 13 0.004018402099609376 -0.0003600000594308206
# 14 0.004019619750976564 0.00014949578178669043
# 15 0.004019010925292971 -0.0001052442933491271
# 16 0.0040193153381347674 2.212770536935693e-05
# 17 0.004019163131713869 -4.155780362768979e-05
# 18 0.004019239234924319 -9.714926586301686e-06
# 19 0.004019277286529543 6.206420035681504e-06
# 20 0.004019258260726931 -1.754245614549177e-06
# 21 0.004019267773628237 2.226089125478836e-06
# ...

# %%
#task 2
# Newton Raphson Method for finding the root

# %matplotlib notebook
def f(x):
    E = sqrt(10-x)*tan(sqrt(10-x))-sqrt(x)
    return E
x = 9 ; dx = 3e-1 ; n = 300 ; eps = 1e-13      #eps = 0.00002    #eps=0.2


for i in range (0,n+1):
    F = f(x)
    if abs(f(x)) <= eps:
        print ("\n\nThe root is found = ",x,"\n\nThe residue f(x)=",f(x),"\n\nWith precision=  ",eps)
        break
    print(i,"\t",x,"\t",f(x))
    
    df = (f(x+dx/2)-f(x-dx/2))/dx
    dx = -F/df
    x += dx
    if i == n :
        print("root Not found")

# No need to plot the tan function again 
#x = arange(6,9,0.01)
#plt.plot(x,f(x))
#plt.grid()
#plt.show()
# Out:
# 0 	 9 	 -1.4425922753450977
# 1 	 8.462189102355724 	 0.7030563101025789
# 2 	 8.568554073487059 	 0.11796190478986723
# 3 	 8.592214175153929 	 0.0027227779584038103
# 4 	 8.592784925464331 	 1.6667135120940202e-06
# 5 	 8.592785275229708 	 6.217248937900877e-13
#
#
# The root is found =  8.592785275229838
#
# The residue f(x)= 3.552713678800501e-15
#
# With precision=   1e-13

# %%
#Newton Raphson method
# %matplotlib notebook
def f(x):
    return 2*cos(x)-x
x = 4 ; dx = 3e-1 ; n = 100 ; eps = 0.2
for i in range (0,n+1):
    F = f(x)
    if abs(F)<=eps:
        print("the root is equal to the value= ",x,"\n\nwith precision eps= : ",eps, "\n\nThe residue F =",F)
        break
    df = (f(x+dx/2)-f(x-dx/2))/dx
    dx = -F/df
    x += dx
    if i == n:
        print ("root NOT found")
# Out:
# the root is equal to the value=  1.013663545694694
#
# with precision eps= :  0.2
#
# The residue F = 0.04384595822041604

# %% [markdown]
# # 7.5 Problem 3: FITTING AN EXPERIMENT SPECTRUM

# %% [markdown]
# # Data Fitting Using Lagrange polynomial Function and Spline (Page 150)

# %% [markdown]
# ![](10.jpg)

# %% [markdown]
# ![](11.jpg)

# %% [markdown]
# ![](12.jpg)

# %% [markdown]
# ![](13.jpg)

# %% [markdown]
# ![](14.jpg)

# %% [markdown]
# # LET'S CODE DATA FITTING

# %% [markdown]
# ![](lagrange.jpg)

# %%
#Task 1 
x= array([0,25,50,75,100,125,150,175,200],float)     #E, Energy
y= array([10.6,16.0,45,83.5,52.8,19.9,10.8,8.25,4.7],float) #g, Cross-section scattering

l = len(x)   #length of the data
n = l-1 #polynomial degree
xp =float(input("Enter the value of E whose P is needed="))
P =0     #P capital initialize
for i in range(n+1):
    p=1   #initialize the product
    for j in range(n+1):
        if j !=i:
            p *= (xp-x[j])/(x[i]-x[j])
    P +=y[i]*p

print(P)
# Out:
# Enter the value of E whose P is needed=200
# 4.7

# %%
#Data given in the task for fitting using lagrange, from Table 7.1
E = array([0,25,50,75,100,125,150,175,200],float)
g = array([10.6,16.0,45,83.5,52.8,19.9,10.8,8.25,4.7],float)


#For the Lagrange method
E_Lagrange = linspace(E[0],E[-1],100)   #lets create a new dataset
g_Lagrange =array([],float)     #empty array

#lets apply a spline function on our function/plot   
#check scipy, spline
E_smooth = linspace(E.min(),E.max(),100)
g_interp = interpolate.splrep(E, g, s=0)
g_smooth = interpolate.splev(E_smooth, g_interp, der=0)

#see the slide above for the formula
for e in E_Lagrange:
    yp =0
    for xi,yi in zip(E,g):
        yp += yi*prod((e-E[E!=xi])/(xi-E[E!=xi]))    #applying conditional indices /index
    g_Lagrange = append(g_Lagrange,yp)
    

plt.figure(figsize=(10,5))    

plt.subplot(151)
plt.plot(E,g,"r-o")
plt.grid()
plt.title("Original data")
plt.xlabel("Energy, E /MeV")
plt.ylabel("Scattering Cross-section")

plt.subplot(153)
plt.plot(E_smooth,g_smooth, "-o")
plt.grid()
plt.title("Spline smoothed")
plt.xlabel("Energy, E /MeV")
plt.ylabel("Scattering Cross-section")

plt.subplot(155)
plt.plot(E_Lagrange,g_Lagrange,"-.")    #Lagrange fitting plot
plt.grid()
plt.xlabel("Energy, E /MeV")
plt.title("Lagrange fitting")
plt.ylabel("Scattering Cross-section")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(11,6))    
#combined figure
plt.plot(E,g,"r-o")
plt.plot(E_smooth,g_smooth)
plt.plot(E_Lagrange,g_Lagrange,"-.")
plt.grid()
plt.legend(["g_Original","g_smooth_spline","gplt_Lagrange"])
plt.ylabel("Scattering Cross-section")
plt.xlabel("Energy, E  /(MeV)")
plt.title('A plot of scattering cross-section versus Energy')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1100">
